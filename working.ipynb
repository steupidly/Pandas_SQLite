# %% [markdown]
# Create Database SQLite

# %%
import sqlite3 as sq3

# %%
#connecting
con = sq3.connect('movies.db')

# %%
con

# %%
con.execute('select * from sqlite_master').fetchall()
# Out:
# []

# %%
con.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name").fetchall()
# Out:
# []

# %%
con.close()

# %% [markdown]
# Load data into database

# %%
import pandas as pd
import json
import numpy as np

pd.options.display.float_format= '{:.2f}'.format

# %%
with open('some_movies.json') as f:
    data = json.load(f)

# %%
df = pd.json_normalize(data, sep='_')
df.head()
# Out:
#    adult                     backdrop_path     budget  \
# 0  False  /orjiB3oUIsyz60hoEqkiGpy5CeO.jpg  356000000
# 1  False  /wcC7kCICL6x6zHUlUyNp9pWoqW1.jpg  237000000
# 2  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
# 3  False  /lmZFxXgJE3vgrciwuDib0N8CfQo.jpg  300000000
# 4  False  /6VmFqApQRyZZzmiGOQq2C92jyvH.jpg  200000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                             homepage      id    imdb_id  \
# 0     https://www.marvel.com/movies/avengers-endgame  299534  tt4154796
# 1                        http://www.avatarmovie.com/   19995  tt0499549
# 2  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# ...

# %%
movies = df[["id", "title", "revenue", "budget", "belongs_to_collection_name", "release_date"]].copy()
movies
# Out:
#         id                                         title     revenue  \
# 0   299534                             Avengers: Endgame  2797800564
# 1    19995                                        Avatar  2787965087
# 2   140607                  Star Wars: The Force Awakens  2068223624
# 3   299536                        Avengers: Infinity War  2046239637
# 4      597                                       Titanic  1845034188
# 5   135397                                Jurassic World  1671713208
# 6   420818                                 The Lion King  1656943394
# 7    24428                                  The Avengers  1519557910
# 8   168259                                     Furious 7  1515047671
# 9    99861                       Avengers: Age of Ultron  1405403694
# 10  284054                                 Black Panther  1346739107
# 11   12445  Harry Potter and the Deathly Hallows: Part 2  1341511219
# 12  181808                      Star Wars: The Last Jedi  1332539889
# ...

# %%
movies.release_date = pd.to_datetime(movies.release_date)

# %%
movies.revenue = movies.revenue.div(1000000)
movies.rename(columns={'revenue':'revenue_musd'}, inplace=True)
movies.head()
# Out:
#        id                         title  revenue_musd     budget  \
# 0  299534             Avengers: Endgame       2797.80  356000000
# 1   19995                        Avatar       2787.97  237000000
# 2  140607  Star Wars: The Force Awakens       2068.22  245000000
# 3  299536        Avengers: Infinity War       2046.24  300000000
# 4     597                       Titanic       1845.03  200000000
#
#   belongs_to_collection_name release_date
# 0    The Avengers Collection   2019-04-24
# 1          Avatar Collection   2009-12-10
# 2       Star Wars Collection   2015-12-15
# 3    The Avengers Collection   2018-04-25
# 4                        NaN   1997-11-18

# %%
movies.budget = movies.budget.div(1000000)
movies.rename(columns={'budget':'budget_musd'}, inplace=True)
movies
# Out:
#         id                                         title  revenue_musd  \
# 0   299534                             Avengers: Endgame       2797.80
# 1    19995                                        Avatar       2787.97
# 2   140607                  Star Wars: The Force Awakens       2068.22
# 3   299536                        Avengers: Infinity War       2046.24
# 4      597                                       Titanic       1845.03
# 5   135397                                Jurassic World       1671.71
# 6   420818                                 The Lion King       1656.94
# 7    24428                                  The Avengers       1519.56
# 8   168259                                     Furious 7       1515.05
# 9    99861                       Avengers: Age of Ultron       1405.40
# 10  284054                                 Black Panther       1346.74
# 11   12445  Harry Potter and the Deathly Hallows: Part 2       1341.51
# ...

# %%
votes = df[['id', 'vote_count','vote_average']].copy()
votes
# Out:
#         id  vote_count  vote_average
# 0   299534       12607          8.30
# 1    19995       21000          7.40
# 2   140607       14205          7.40
# 3   299536       17718          8.30
# 4      597       16661          7.80
# 5   135397       15399          6.60
# 6   420818        5425          7.20
# 7    24428       22101          7.70
# 8   168259        7359          7.30
# 9    99861       15548          7.30
# 10  284054       14830          7.40
# 11   12445       13447          8.10
# 12  181808       10304          7.00
# 13  330457        3982          7.20
# 14  351286        7337          6.50
# 15  109445       11616          7.30
# 16  321612       12203          6.90
# 17  260513        8147          7.50

# %%
#normalize satu column json menjadi df baru 
genres = pd.json_normalize(data=data, record_path='genres',meta='id',record_prefix='genres_')
genres
# Out:
#     genres_id      genres_name      id
# 0          12        Adventure  299534
# 1         878  Science Fiction  299534
# 2          28           Action  299534
# 3          28           Action   19995
# 4          12        Adventure   19995
# 5          14          Fantasy   19995
# 6         878  Science Fiction   19995
# 7          28           Action  140607
# 8          12        Adventure  140607
# 9         878  Science Fiction  140607
# 10         14          Fantasy  140607
# 11         12        Adventure  299536
# 12         28           Action  299536
# 13        878  Science Fiction  299536
# 14         18            Drama     597
# 15      10749          Romance     597
# 16         28           Action  135397
# 17         12        Adventure  135397
# 18        878  Science Fiction  135397
# 19         53         Thriller  135397
# 20         12        Adventure  420818
# 21      10751           Family  420818
# 22        878  Science Fiction   24428
# ...

# %%
prod = pd.json_normalize(data=data, record_path='production_companies', meta='id', record_prefix='comp_')
prod
# Out:
#     comp_id                    comp_logo_path  \
# 0       420  /hUzeosd33nzE5MCNsZxCGEKTXaQ.png
# 1       444  /42UPdZl6B2cFXgNUASR8hSt9mpS.png
# 2       574  /iB6GjNVHs5hOqcEYt2rcjBqIjki.png
# 3        25  /qZCc1lty5FzX30aOCVRBLzaVmcp.png
# 4       290   /Q8mw2AOQQc8Qg0uNwLWq86DVZv.png
# 5      1634                              None
# 6         1  /o86DbpburjxrqAzEDhXZcyE8pDb.png
# 7     11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png
# 8       420  /hUzeosd33nzE5MCNsZxCGEKTXaQ.png
# 9         4  /fycMZt242LVjagMByZOLUGbCvv3.png
# 10      574  /iB6GjNVHs5hOqcEYt2rcjBqIjki.png
# 11       25  /qZCc1lty5FzX30aOCVRBLzaVmcp.png
# 12     3341  /dTG5dXE1kU2mpmL9BNnraffckLU.png
# 13       56  /cEaxANEisCqeEoRvODv2dO1I0iI.png
# 14      923  /5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png
# 15       33  /8lvHyhjr8oUKOOy2dKXoALWKdp0.png
# 16     1778  /69xm6sF3JxugGVjfZfm1YY6d7EE.png
# 17      862  /udTjbqPmcTbfrihMuLtLcizDEM1.png
# 18        2  /wdrCwmRnLFJhEoH8GSfymY85KHT.png
# ...

# %%
con = sq3.connect('movies.db')

# %%
con

# %%
movies.to_sql('Movies',con, index=False)
# Out:
# 18

# %%
votes.to_sql('Votes',con, index=False)
# Out:
# 18

# %%
genres.to_sql('Genres',con, index=False)
# Out:
# 55

# %%
prod.to_sql('Production',con,index=False)
# Out:
# 52

# %%
con.execute("select * From sqlite_master").fetchall()
# Out:
# [('table',
#   'Movies',
#   'Movies',
#   2,
#   'CREATE TABLE "Movies" (\n"id" INTEGER,\n  "title" TEXT,\n  "revenue_musd" REAL,\n  "budget_musd" REAL,\n  "belongs_to_collection_name" TEXT,\n  "release_date" TIMESTAMP\n)'),
#  ('table',
#   'Votes',
#   'Votes',
#   3,
#   'CREATE TABLE "Votes" (\n"id" INTEGER,\n  "vote_count" INTEGER,\n  "vote_average" REAL\n)'),
#  ('table',
#   'Genres',
#   'Genres',
#   4,
#   'CREATE TABLE "Genres" (\n"genres_id" INTEGER,\n  "genres_name" TEXT,\n  "id" INTEGER\n)'),
#  ('table',
#   'Production',
#   'Production',
#   5,
#   'CREATE TABLE "Production" (\n"comp_id" INTEGER,\n  "comp_logo_path" TEXT,\n  "comp_name" TEXT,\n  "comp_origin_country" TEXT,\n  "id" INTEGER\n)')]

# %%
con.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name").fetchall()
# Out:
# [('Genres',), ('Movies',), ('Production',), ('Votes',)]

# %%
con.close()

# %% [markdown]
# How to load data from SQLite into DataFrames

# %%
con= sq3.connect('movies.db')

# %%
pd.read_sql('select * from production',con)
# Out:
#     comp_id                    comp_logo_path  \
# 0       420  /hUzeosd33nzE5MCNsZxCGEKTXaQ.png
# 1       444  /42UPdZl6B2cFXgNUASR8hSt9mpS.png
# 2       574  /iB6GjNVHs5hOqcEYt2rcjBqIjki.png
# 3        25  /qZCc1lty5FzX30aOCVRBLzaVmcp.png
# 4       290   /Q8mw2AOQQc8Qg0uNwLWq86DVZv.png
# 5      1634                              None
# 6         1  /o86DbpburjxrqAzEDhXZcyE8pDb.png
# 7     11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png
# 8       420  /hUzeosd33nzE5MCNsZxCGEKTXaQ.png
# 9         4  /fycMZt242LVjagMByZOLUGbCvv3.png
# 10      574  /iB6GjNVHs5hOqcEYt2rcjBqIjki.png
# 11       25  /qZCc1lty5FzX30aOCVRBLzaVmcp.png
# 12     3341  /dTG5dXE1kU2mpmL9BNnraffckLU.png
# 13       56  /cEaxANEisCqeEoRvODv2dO1I0iI.png
# 14      923  /5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png
# 15       33  /8lvHyhjr8oUKOOy2dKXoALWKdp0.png
# 16     1778  /69xm6sF3JxugGVjfZfm1YY6d7EE.png
# 17      862  /udTjbqPmcTbfrihMuLtLcizDEM1.png
# 18        2  /wdrCwmRnLFJhEoH8GSfymY85KHT.png
# ...

# %%
#, membuat id jadi index, mengubah tipe release_date jadi datetime
df = pd.read_sql('select * from movies', con, index_col='id', parse_dates='release_date')
df
# Out:
#                                                title  revenue_musd  \
# id
# 299534                             Avengers: Endgame       2797.80
# 19995                                         Avatar       2787.97
# 140607                  Star Wars: The Force Awakens       2068.22
# 299536                        Avengers: Infinity War       2046.24
# 597                                          Titanic       1845.03
# 135397                                Jurassic World       1671.71
# 420818                                 The Lion King       1656.94
# 24428                                   The Avengers       1519.56
# 168259                                     Furious 7       1515.05
# 99861                        Avengers: Age of Ultron       1405.40
# 284054                                 Black Panther       1346.74
# 12445   Harry Potter and the Deathly Hallows: Part 2       1341.51
# 181808                      Star Wars: The Last Jedi       1332.54
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 299534 to 260513
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   title                       18 non-null     object
#  1   revenue_musd                18 non-null     float64
#  2   budget_musd                 18 non-null     float64
#  3   belongs_to_collection_name  15 non-null     object
#  4   release_date                18 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 864.0+ bytes

# %%
genres = pd.read_sql('select*from genres',con, index_col='id')
genres
# Out:
#         genres_id      genres_name
# id
# 299534         12        Adventure
# 299534        878  Science Fiction
# 299534         28           Action
# 19995          28           Action
# 19995          12        Adventure
# 19995          14          Fantasy
# 19995         878  Science Fiction
# 140607         28           Action
# 140607         12        Adventure
# 140607        878  Science Fiction
# 140607         14          Fantasy
# 299536         12        Adventure
# 299536         28           Action
# 299536        878  Science Fiction
# 597            18            Drama
# 597         10749          Romance
# 135397         28           Action
# 135397         12        Adventure
# 135397        878  Science Fiction
# 135397         53         Thriller
# 420818         12        Adventure
# 420818      10751           Family
# 24428         878  Science Fiction
# 24428          28           Action
# 24428          12        Adventure
# ...

# %%
con.close()

# %%
con = sq3.connect('movies.db')

# %%
pd.read_sql('select * from Movies',con)
# Out:
#         id                                         title  revenue_musd  \
# 0   299534                             Avengers: Endgame       2797.80
# 1    19995                                        Avatar       2787.97
# 2   140607                  Star Wars: The Force Awakens       2068.22
# 3   299536                        Avengers: Infinity War       2046.24
# 4      597                                       Titanic       1845.03
# 5   135397                                Jurassic World       1671.71
# 6   420818                                 The Lion King       1656.94
# 7    24428                                  The Avengers       1519.56
# 8   168259                                     Furious 7       1515.05
# 9    99861                       Avengers: Age of Ultron       1405.40
# 10  284054                                 Black Panther       1346.74
# 11   12445  Harry Potter and the Deathly Hallows: Part 2       1341.51
# ...

# %%
pd.read_sql('select * \
                from Movies',con)
# Out:
#         id                                         title  revenue_musd  \
# 0   299534                             Avengers: Endgame       2797.80
# 1    19995                                        Avatar       2787.97
# 2   140607                  Star Wars: The Force Awakens       2068.22
# 3   299536                        Avengers: Infinity War       2046.24
# 4      597                                       Titanic       1845.03
# 5   135397                                Jurassic World       1671.71
# 6   420818                                 The Lion King       1656.94
# 7    24428                                  The Avengers       1519.56
# 8   168259                                     Furious 7       1515.05
# 9    99861                       Avengers: Age of Ultron       1405.40
# 10  284054                                 Black Panther       1346.74
# 11   12445  Harry Potter and the Deathly Hallows: Part 2       1341.51
# ...

# %%
pd.read_sql('select id, revenue_musd, release_date from Movies',con)
# Out:
#         id  revenue_musd         release_date
# 0   299534       2797.80  2019-04-24 00:00:00
# 1    19995       2787.97  2009-12-10 00:00:00
# 2   140607       2068.22  2015-12-15 00:00:00
# 3   299536       2046.24  2018-04-25 00:00:00
# 4      597       1845.03  1997-11-18 00:00:00
# 5   135397       1671.71  2015-06-06 00:00:00
# 6   420818       1656.94  2019-07-12 00:00:00
# 7    24428       1519.56  2012-04-25 00:00:00
# 8   168259       1515.05  2015-04-01 00:00:00
# 9    99861       1405.40  2015-04-22 00:00:00
# 10  284054       1346.74  2018-02-13 00:00:00
# 11   12445       1341.51  2011-07-07 00:00:00
# 12  181808       1332.54  2017-12-13 00:00:00
# 13  330457       1330.76  2019-11-20 00:00:00
# 14  351286       1303.46  2018-06-06 00:00:00
# 15  109445       1274.22  2013-11-27 00:00:00
# 16  321612       1263.52  2017-03-16 00:00:00
# 17  260513       1241.89  2018-06-14 00:00:00

# %% [markdown]
# Some simple queries

# %%
pd.read_sql('select sum(revenue_musd)from movies',con )
# Out:
#    sum(revenue_musd)
# 0           29748.58

# %%
con.execute('select sum(revenue_musd) from movies').fetchall()[0][0]
# Out:
# 29748.575327000002

# %%
pd.read_sql('select count(title) from movies',con)
# Out:
#    count(title)
# 0            18

# %%
con.execute('select count(title) from movies').fetchall()[0][0]
# Out:
# 18

# %%
pd.read_sql('select count(*) from movies',con)
# Out:
#    count(*)
# 0        18

# %%
pd.read_sql('select avg(budget_musd)from movies',con)
# Out:
#    avg(budget_musd)
# 0            209.06

# %%
con.close()

# %%
con= sq3.connect('movies.db')

# %%
pd.read_sql("SELECT * FROM MOVIES WHERE id = 597", con)
# Out:
#     id    title  revenue_musd  budget_musd belongs_to_collection_name  \
# 0  597  Titanic       1845.03       200.00                       None
#
#           release_date
# 0  1997-11-18 00:00:00

# %%
pd.read_sql('select * from movies where revenue_musd >= 2000', con)
# Out:
#        id                         title  revenue_musd  budget_musd  \
# 0  299534             Avengers: Endgame       2797.80       356.00
# 1   19995                        Avatar       2787.97       237.00
# 2  140607  Star Wars: The Force Awakens       2068.22       245.00
# 3  299536        Avengers: Infinity War       2046.24       300.00
#
#   belongs_to_collection_name         release_date
# 0    The Avengers Collection  2019-04-24 00:00:00
# 1          Avatar Collection  2009-12-10 00:00:00
# 2       Star Wars Collection  2015-12-15 00:00:00
# 3    The Avengers Collection  2018-04-25 00:00:00

# %%
pd.read_sql('select * from movies where revenue_musd > 1500 AND budget_musd < 200',con)
# Out:
#        id           title  revenue_musd  budget_musd  \
# 0  135397  Jurassic World       1671.71       150.00
# 1  168259       Furious 7       1515.05       190.00
#
#             belongs_to_collection_name         release_date
# 0             Jurassic Park Collection  2015-06-06 00:00:00
# 1  The Fast and the Furious Collection  2015-04-01 00:00:00

# %%
pd.read_sql('select min(budget_musd)  from movies where revenue_musd >= 1250 ',con)
# Out:
#    min(budget_musd)
# 0            125.00

# %%
pd.read_sql('select distinct title from movies',con)
# Out:
#                                            title
# 0                              Avengers: Endgame
# 1                                         Avatar
# 2                   Star Wars: The Force Awakens
# 3                         Avengers: Infinity War
# 4                                        Titanic
# 5                                 Jurassic World
# 6                                  The Lion King
# 7                                   The Avengers
# 8                                      Furious 7
# 9                        Avengers: Age of Ultron
# 10                                 Black Panther
# 11  Harry Potter and the Deathly Hallows: Part 2
# 12                      Star Wars: The Last Jedi
# 13                                     Frozen II
# 14                Jurassic World: Fallen Kingdom
# 15                                        Frozen
# 16                          Beauty and the Beast
# 17                                 Incredibles 2

# %%
pd.read_sql('select * from movies order by budget_musd desc',con)
# Out:
#         id                                         title  revenue_musd  \
# 0   299534                             Avengers: Endgame       2797.80
# 1   299536                        Avengers: Infinity War       2046.24
# 2   420818                                 The Lion King       1656.94
# 3    99861                       Avengers: Age of Ultron       1405.40
# 4   140607                  Star Wars: The Force Awakens       2068.22
# 5    19995                                        Avatar       2787.97
# 6    24428                                  The Avengers       1519.56
# 7      597                                       Titanic       1845.03
# 8   284054                                 Black Panther       1346.74
# 9   181808                      Star Wars: The Last Jedi       1332.54
# 10  260513                                 Incredibles 2       1241.89
# 11  168259                                     Furious 7       1515.05
# ...

# %%
pd.read_sql("SELECT DISTINCT belongs_to_collection_name FROM Movies", con)
# Out:
#             belongs_to_collection_name
# 0              The Avengers Collection
# 1                    Avatar Collection
# 2                 Star Wars Collection
# 3                                 None
# 4             Jurassic Park Collection
# 5  The Fast and the Furious Collection
# 6             Black Panther Collection
# 7              Harry Potter Collection
# 8                    Frozen Collection
# 9           The Incredibles Collection

# %%
pd.read_sql("SELECT * FROM Movies WHERE belongs_to_collection_name IS NULL", con)
# Out:
#        id                 title  revenue_musd  budget_musd  \
# 0     597               Titanic       1845.03       200.00
# 1  420818         The Lion King       1656.94       260.00
# 2  321612  Beauty and the Beast       1263.52       160.00
#
#   belongs_to_collection_name         release_date
# 0                       None  1997-11-18 00:00:00
# 1                       None  2019-07-12 00:00:00
# 2                       None  2017-03-16 00:00:00

# %%
pd.read_sql("SELECT * FROM Movies WHERE belongs_to_collection_name IS NOT NULL", con)
# Out:
#         id                                         title  revenue_musd  \
# 0   299534                             Avengers: Endgame       2797.80
# 1    19995                                        Avatar       2787.97
# 2   140607                  Star Wars: The Force Awakens       2068.22
# 3   299536                        Avengers: Infinity War       2046.24
# 4   135397                                Jurassic World       1671.71
# 5    24428                                  The Avengers       1519.56
# 6   168259                                     Furious 7       1515.05
# 7    99861                       Avengers: Age of Ultron       1405.40
# 8   284054                                 Black Panther       1346.74
# 9    12445  Harry Potter and the Deathly Hallows: Part 2       1341.51
# 10  181808                      Star Wars: The Last Jedi       1332.54
# 11  330457                                     Frozen II       1330.76
# ...

# %%
pd.read_sql("select * from movies where title like'%Avengers%' ",con)
# Out:
#        id                    title  revenue_musd  budget_musd  \
# 0  299534        Avengers: Endgame       2797.80       356.00
# 1  299536   Avengers: Infinity War       2046.24       300.00
# 2   24428             The Avengers       1519.56       220.00
# 3   99861  Avengers: Age of Ultron       1405.40       250.00
#
#   belongs_to_collection_name         release_date
# 0    The Avengers Collection  2019-04-24 00:00:00
# 1    The Avengers Collection  2018-04-25 00:00:00
# 2    The Avengers Collection  2012-04-25 00:00:00
# 3    The Avengers Collection  2015-04-22 00:00:00

# %%
con.close()

# %% [markdown]
# Join Query

# %%
con=sq3.connect('movies.db')

# %%
pd.read_sql('SELECT * FROM MOVIES\
            JOIN VOTES \
            ON MOVIES.ID = VOTES.ID', con)
# Out:
#         id                                         title  revenue_musd  \
# 0   299534                             Avengers: Endgame       2797.80
# 1    19995                                        Avatar       2787.97
# 2   140607                  Star Wars: The Force Awakens       2068.22
# 3   299536                        Avengers: Infinity War       2046.24
# 4      597                                       Titanic       1845.03
# 5   135397                                Jurassic World       1671.71
# 6   420818                                 The Lion King       1656.94
# 7    24428                                  The Avengers       1519.56
# 8   168259                                     Furious 7       1515.05
# 9    99861                       Avengers: Age of Ultron       1405.40
# 10  284054                                 Black Panther       1346.74
# 11   12445  Harry Potter and the Deathly Hallows: Part 2       1341.51
# ...

# %%
pd.read_sql('select m.id, title, v.vote_average from movies as m\
            join votes as v\
            on m.id = v.id order by m.id',con,index_col='id')
# Out:
#                                                title  vote_average
# id
# 597                                          Titanic          7.80
# 12445   Harry Potter and the Deathly Hallows: Part 2          8.10
# 19995                                         Avatar          7.40
# 24428                                   The Avengers          7.70
# 99861                        Avengers: Age of Ultron          7.30
# 109445                                        Frozen          7.30
# 135397                                Jurassic World          6.60
# 140607                  Star Wars: The Force Awakens          7.40
# 168259                                     Furious 7          7.30
# 181808                      Star Wars: The Last Jedi          7.00
# 260513                                 Incredibles 2          7.50
# 284054                                 Black Panther          7.40
# 299534                             Avengers: Endgame          8.30
# ...

# %%
pd.read_sql("select m.id, title, vote_average from movies as m\
            join votes as v \
            on m.id = v.id\
            where vote_average > 8 order by m.id  ",con, index_col= 'id')
# Out:
#                                                title  vote_average
# id
# 12445   Harry Potter and the Deathly Hallows: Part 2          8.10
# 299534                             Avengers: Endgame          8.30
# 299536                        Avengers: Infinity War          8.30

# %%
pd.read_sql('select m.id, title, vote_average, budget_musd from movies m\
            join votes v on m.id=v.id\
            where vote_average > 8 order by budget_musd asc',con,index_col='id')
# Out:
#                                                title  vote_average  \
# id
# 12445   Harry Potter and the Deathly Hallows: Part 2          8.10
# 299536                        Avengers: Infinity War          8.30
# 299534                             Avengers: Endgame          8.30
#
#         budget_musd
# id
# 12445        125.00
# 299536       300.00
# 299534       356.00

# %%
prod
# Out:
#     comp_id                    comp_logo_path  \
# 0       420  /hUzeosd33nzE5MCNsZxCGEKTXaQ.png
# 1       444  /42UPdZl6B2cFXgNUASR8hSt9mpS.png
# 2       574  /iB6GjNVHs5hOqcEYt2rcjBqIjki.png
# 3        25  /qZCc1lty5FzX30aOCVRBLzaVmcp.png
# 4       290   /Q8mw2AOQQc8Qg0uNwLWq86DVZv.png
# 5      1634                              None
# 6         1  /o86DbpburjxrqAzEDhXZcyE8pDb.png
# 7     11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png
# 8       420  /hUzeosd33nzE5MCNsZxCGEKTXaQ.png
# 9         4  /fycMZt242LVjagMByZOLUGbCvv3.png
# 10      574  /iB6GjNVHs5hOqcEYt2rcjBqIjki.png
# 11       25  /qZCc1lty5FzX30aOCVRBLzaVmcp.png
# 12     3341  /dTG5dXE1kU2mpmL9BNnraffckLU.png
# 13       56  /cEaxANEisCqeEoRvODv2dO1I0iI.png
# 14      923  /5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png
# 15       33  /8lvHyhjr8oUKOOy2dKXoALWKdp0.png
# 16     1778  /69xm6sF3JxugGVjfZfm1YY6d7EE.png
# 17      862  /udTjbqPmcTbfrihMuLtLcizDEM1.png
# 18        2  /wdrCwmRnLFJhEoH8GSfymY85KHT.png
# ...

# %%
pd.read_sql('select m.id, sum(revenue_musd), comp_name from movies as m\
            join production as p on m.id=p.id group by comp_name',con,index_col='id')
# Out:
#         sum(revenue_musd)                                    comp_name
# id
# 19995             4633.00                             20th Century Fox
# 168259            1515.05                    Abu Dhabi Film Commission
# 135397            2975.17                         Amblin Entertainment
# 140607            2068.22                                    Bad Robot
# 168259            1515.05                               China Film Co.
# 168259            1515.05  Colorado Office of Film, Television & Media
# 135397            3186.76                                       Dentsu
# 19995             2787.97                           Dune Entertainment
# 420818            1656.94                       Fairview Entertainment
# 135397            3186.76                      Fuji Television Network
# 12445             1341.51                                 Heyday Films
# 19995             2787.97                              Ingenious Media
# ...

# %%
pd.read_sql("select comp_name  from movies as m join production as p\
            on m.id=p.id where title like '%Titanic%' ",con)
# Out:
#                   comp_name
# 0          20th Century Fox
# 1  Lightstorm Entertainment
# 2                 Paramount

# %%
pd.read_sql('select m.id, sum(revenue_musd), genres_name from movies as m\
            join genres as g on  m.id=g.id\
            group by genres_name',con, index_col='id')
# Out:
#         sum(revenue_musd)      genres_name
# id
# 299534           21036.58           Action
# 299534           25124.97        Adventure
# 330457            3846.88        Animation
# 597               1845.03            Drama
# 420818            6767.34           Family
# 19995             8807.96          Fantasy
# 597               3108.56          Romance
# 299534           18279.64  Science Fiction
# 135397            3186.76         Thriller

# %%
pd.read_sql("select genres_name from movies as m join genres as g\
            on m.id=g.id where title like '%Frozen II%' ",con)
# Out:
#   genres_name
# 0   Adventure
# 1   Animation
# 2      Family

# %%
con.close()
